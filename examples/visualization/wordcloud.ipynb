# %%
import pyexcel as p

data= [
    ['pyexcel', 310],
    ['django-excel', 110],
    ['Flask-excel', 90],
    ['pyexcel-io', 14]
]

sheet = p.Sheet(data)
sheet.plot.wordcloud()
# Out:
# <StringIO.StringIO instance at 0x112310cb0>
