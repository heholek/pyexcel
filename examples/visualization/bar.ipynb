# %%
import pyecharts as charts
charts.online()

import pyexcel as p

csv_content = """,Structural height,Longest span,Country
Millau Viaduct,343,342,France
Yavuz Sultan Selim Bridge,322,1408,Turkey
Russky Bridge,320.9,1104,Russia
Sutong Bridge,306,1008,China
Stonecutters Bridge, 298,1018,Hong Kong
Chishi Bridge,288,380,China
Akashi Kaikyo Bridge,282.8,1991,Japan
Yi Sun-sin Bridge,270,1545,South Korea
Duge Bridge,269,720,China
Jingyue Bridge,265,816,China
"""

sheet = p.get_sheet(file_content=csv_content, file_type='csv')
sheet.transpose()
del(sheet.row[3]) # do not plot country
sheet.plot.bar()
# Out:
# <StringIO.StringIO instance at 0x11219f7e8>
